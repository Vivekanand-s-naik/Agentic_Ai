# %%
from pathlib import Path

"""
# 1. creating path oibjets and geting thge cwd and home directory 
# 2. Reading and writing trhe fils withjout opening the file
3. Directory search (glob and rglob)
4. Directory Operations (exists, is_file, is_dir)
5. Extracting the Path Components (name, parent Directory, stem(name without extension ), parent folder)
"""
pobj = Path("../doc_files/SowmyaG_Resume.pdf")
# print(pobj.cwd())
# print(pobj.home())

# print(pobj.read_text())
# print(pobj.read_bytes())

# print(pobj.write_text(data='{"role": "admin"}'))
# print(pobj.read_text())

# print(list(pobj.rglob("**/*.pdf")))

# print(pobj.is_file())
# print(pobj.is_dir())
# print(pobj.name)
# print(pobj.stem)
# print(pobj.suffix)
# print(pobj.parent)
# Out:
# True
# False
# SowmyaG_Resume.pdf
# SowmyaG_Resume
# .pdf
# ..\doc_files
